# %% [markdown]
# # Chinese Understanding Benchmark: Qwen3.5-4B vs Gemma E4B
#
# This notebook evaluates and fine-tunes two small language models on standard Chinese language understanding datasets from CLUE.
#
# Default models:
# - `Qwen/Qwen3.5-4B`
# - `google/gemma-4-E4B`
#
# Default CLUE tasks:
# - `afqmc`: sentence-pair semantic matching
# - `tnews`: news title classification
# - `cmnli`: natural language inference
#
# Designed for a 32GB Apple Silicon Mac. Start with baseline evaluation first. Fine-tuning is optional and uses LoRA, not full fine-tuning.

# %% [markdown]
# ## 1. Install dependencies

# %%
# %pip install -U torch transformers datasets accelerate peft trl scikit-learn pandas tqdm sentencepiece protobuf
# Out:
# Requirement already satisfied: torch in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (2.12.0)
# Requirement already satisfied: transformers in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (5.8.1)
# Requirement already satisfied: datasets in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (4.8.5)
# Requirement already satisfied: accelerate in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (1.13.0)
# Requirement already satisfied: peft in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (0.19.1)
# Requirement already satisfied: trl in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (1.4.0)
# Requirement already satisfied: scikit-learn in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: pandas in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (3.0.3)
# Requirement already satisfied: tqdm in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (4.67.3)
# Requirement already satisfied: sentencepiece in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (0.2.1)
# Requirement already satisfied: protobuf in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (7.34.1)
# Requirement already satisfied: filelock in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from torch) (4.13.2)
# Requirement already satisfied: setuptools<82 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from torch) (73.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from torch) (2025.3.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from transformers) (1.15.0)
# Requirement already satisfied: numpy>=1.17 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from transformers) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex>=2025.10.22 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from datasets) (24.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from datasets) (0.4.1)
# Requirement already satisfied: requests>=2.32.2 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: httpx<1.0.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from datasets) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.20 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from datasets) (0.70.19)
# Requirement already satisfied: psutil in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: scipy>=1.10.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.5)
# Requirement already satisfied: anyio in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (4.9.0)
# Requirement already satisfied: certifi in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (1.0.7)
# Requirement already satisfied: idna in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.0)
# Requirement already satisfied: six>=1.5 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from typer->transformers) (8.4.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from rich>=13.8.0->typer->transformers) (2.19.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/wwei/miniconda3/envs/nlp1/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. Imports and configuration
#
# Some gated Google models require `huggingface-cli login` before loading. Keep sample counts small at first on a laptop.

# %%
import os, re, time, platform, gc
from typing import Dict, List, Any, Optional
import pandas as pd
import torch
from tqdm.auto import tqdm
from datasets import load_dataset
from sklearn.metrics import accuracy_score, f1_score
from transformers import AutoTokenizer, AutoModelForCausalLM, TrainingArguments

try:
    from peft import LoraConfig, PeftModel
    from trl import SFTTrainer
    PEFT_AVAILABLE = True
except Exception as e:
    print("PEFT/TRL import failed:", e)
    PEFT_AVAILABLE = False

print("Python:", platform.python_version())
print("Torch:", torch.__version__)
print("MPS available:", torch.backends.mps.is_available())
print("CUDA available:", torch.cuda.is_available())
# Out:
# Python: 3.11.9
# Torch: 2.12.0
# MPS available: True
# CUDA available: False

# %%
MODELS = {
    "qwen35_4b": "Qwen/Qwen3.5-4B",
    "gemma_e4b": "google/gemma-4-E4B",
}

TASKS = ["afqmc", "tnews", "cmnli"]
SPLIT = "validation"
MAX_EVAL_SAMPLES = 200      # raise after smoke test
MAX_TRAIN_SAMPLES = 1000    # raise after smoke test
RESULTS_DIR = "results"
ADAPTERS_DIR = "adapters"
os.makedirs(RESULTS_DIR, exist_ok=True)
os.makedirs(ADAPTERS_DIR, exist_ok=True)

if torch.cuda.is_available():
    DEVICE = "cuda"
elif torch.backends.mps.is_available():
    DEVICE = "mps"
else:
    DEVICE = "cpu"
DEVICE
# Out:
# 'mps'

# %% [markdown]
# ## 3. CLUE task definitions and prompts
#
# This uses label-only generation. The model must output one of the allowed labels.

# %%
TASK_LABELS = {
    "afqmc": ["0", "1"],
    "tnews": [str(i) for i in range(15)],
    "cmnli": ["neutral", "entailment", "contradiction"],
}

def build_prompt(task: str, ex: Dict[str, Any], labels: List[str]) -> str:
    label_text = ", ".join(labels)
    if task == "afqmc":
        return f"""你是中文语言理解评测模型。
任务：判断下面两个句子的语义是否相同。0=不同，1=相同。

句子1：{ex['sentence1']}
句子2：{ex['sentence2']}

请只回答一个标签：{label_text}
答案："""
    if task == "tnews":
        return f"""你是中文语言理解评测模型。
任务：判断下面新闻标题的类别。

标题：{ex['sentence']}

请只回答一个标签：{label_text}
答案："""
    if task == "cmnli":
        return f"""你是中文语言理解评测模型。
任务：判断“前提”和“假设”的关系。
可选标签：neutral=中立，entailment=蕴含，contradiction=矛盾。

前提：{ex['sentence1']}
假设：{ex['sentence2']}

请只回答一个标签：{label_text}
答案："""
    raise ValueError(f"Unsupported task: {task}")

def get_gold_label(task: str, ex: Dict[str, Any]) -> str:
    return str(ex["label"])

def extract_label(text: str, labels: List[str]) -> str:
    text = str(text).strip()
    for label in labels:
        if text == label or text.startswith(label):
            return label
    for label in sorted(labels, key=len, reverse=True):
        if re.search(rf"(?<![A-Za-z0-9_]){re.escape(label)}(?![A-Za-z0-9_])", text):
            return label
    return "__invalid__"

# %% [markdown]
# ## 4. Load CLUE datasets

# %%
def load_task_dataset(task: str, split: str = SPLIT, max_samples: Optional[int] = None):
    ds = load_dataset("clue", task, split=split)
    if max_samples is not None:
        ds = ds.select(range(min(max_samples, len(ds))))
    return ds

for task in TASKS:
    ds = load_task_dataset(task, SPLIT, 3)
    print("\n", task, ds)
    print(ds[0])
# Out:
# README.md: 0.00B [00:00, ?B/s]
# afqmc/test-00000-of-00001.parquet:   0%|          | 0.00/211k [00:00<?, ?B/s]
# afqmc/train-00000-of-00001.parquet:   0%|          | 0.00/1.89M [00:00<?, ?B/s]
# afqmc/validation-00000-of-00001.parquet:   0%|          | 0.00/240k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/3861 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/34334 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/4316 [00:00<?, ? examples/s]
#  afqmc Dataset({
#     features: ['sentence1', 'sentence2', 'label', 'idx'],
#     num_rows: 3
# })
# {'sentence1': '双十一花呗提额在哪', 'sentence2': '里可以提花呗额度', 'label': 0, 'idx': 0}
# tnews/test-00000-of-00001.parquet:   0%|          | 0.00/655k [00:00<?, ?B/s]
# tnews/train-00000-of-00001.parquet:   0%|          | 0.00/3.40M [00:00<?, ?B/s]
# tnews/validation-00000-of-00001.parquet:   0%|          | 0.00/643k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/53360 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/10000 [00:00<?, ? examples/s]
#  tnews Dataset({
#     features: ['sentence', 'label', 'idx'],
#     num_rows: 3
# })
# {'sentence': '江疏影甜甜圈自拍，迷之角度竟这么好看，美吸引一切事物', 'label': 2, 'idx': 0}
# cmnli/test-00000-of-00001.parquet:   0%|          | 0.00/1.72M [00:00<?, ?B/s]
# cmnli/train-00000-of-00001.parquet:   0%|          | 0.00/51.2M [00:00<?, ?B/s]
# cmnli/validation-00000-of-00001.parquet:   0%|          | 0.00/1.35M [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/13880 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/391783 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/12241 [00:00<?, ? examples/s]
#  cmnli Dataset({
#     features: ['sentence1', 'sentence2', 'label', 'idx'],
#     num_rows: 3
# })
# {'sentence1': '新的权利已经足够好了', 'sentence2': '每个人都很喜欢最新的福利', 'label': 0, 'idx': 0}

# %% [markdown]
# ## 5. Model loading and baseline evaluation
#
# On a 32GB Mac, load/evaluate one model at a time. If memory pressure is high, lower `MAX_EVAL_SAMPLES` or restart the kernel between models.

# %%
def cleanup_memory():
    gc.collect()
    if DEVICE == "mps":
        torch.mps.empty_cache()
    elif DEVICE == "cuda":
        torch.cuda.empty_cache()

def load_causal_lm(model_id: str):
    tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token
    kwargs = dict(trust_remote_code=True)
    if DEVICE == "cuda":
        kwargs.update(torch_dtype=torch.float16, device_map="auto")
    elif DEVICE == "mps":
        kwargs.update(torch_dtype=torch.float16)
    else:
        kwargs.update(torch_dtype=torch.float32)
    model = AutoModelForCausalLM.from_pretrained(model_id, **kwargs)
    if DEVICE in ["mps", "cpu"]:
        model.to(DEVICE)
    model.eval()
    return tokenizer, model

@torch.no_grad()
def generate_answer(tokenizer, model, prompt: str, max_new_tokens: int = 8) -> str:
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=1024)
    inputs = {k: v.to(model.device) for k, v in inputs.items()}
    output = model.generate(**inputs, max_new_tokens=max_new_tokens, do_sample=False, pad_token_id=tokenizer.eos_token_id)
    new_tokens = output[0, inputs["input_ids"].shape[-1]:]
    return tokenizer.decode(new_tokens, skip_special_tokens=True).strip()

def evaluate_model_on_task(model_key: str, model_id: str, task: str, split: str = SPLIT, max_samples: int = MAX_EVAL_SAMPLES):
    labels = TASK_LABELS[task]
    ds = load_task_dataset(task, split, max_samples)
    tokenizer, model = load_causal_lm(model_id)
    rows = []
    start = time.time()
    for ex in tqdm(ds, desc=f"{model_key} / {task}"):
        prompt = build_prompt(task, ex, labels)
        raw = generate_answer(tokenizer, model, prompt)
        pred = extract_label(raw, labels)
        gold = get_gold_label(task, ex)
        rows.append({"model_key": model_key, "model_id": model_id, "task": task, "split": split, "gold": gold, "pred": pred, "raw_output": raw, "prompt": prompt})
    elapsed = time.time() - start
    del model
    cleanup_memory()
    df = pd.DataFrame(rows)
    valid_pred = df["pred"].where(df["pred"].isin(labels), "__invalid__")
    summary = {"model_key": model_key, "model_id": model_id, "task": task, "split": split, "samples": len(df), "accuracy": accuracy_score(df["gold"], valid_pred), "macro_f1": f1_score(df["gold"], valid_pred, average="macro", zero_division=0), "invalid_rate": float((valid_pred == "__invalid__").mean()), "seconds": elapsed, "samples_per_second": len(df) / max(elapsed, 1e-9)}
    return df, summary

# %%
# Baseline evaluation. This can take a while on CPU/MPS.
baseline_rows, baseline_summaries = [], []
for model_key, model_id in MODELS.items():
    for task in TASKS:
        try:
            df_task, summary = evaluate_model_on_task(model_key, model_id, task)
            baseline_rows.append(df_task)
            baseline_summaries.append(summary)
            pd.DataFrame(baseline_summaries).to_csv(f"{RESULTS_DIR}/baseline_summary.csv", index=False)
            pd.concat(baseline_rows, ignore_index=True).to_csv(f"{RESULTS_DIR}/baseline_predictions.csv", index=False)
            print(summary)
        except Exception as e:
            print(f"FAILED: {model_key} / {task}: {type(e).__name__}: {e}")

baseline_summary_df = pd.DataFrame(baseline_summaries)
baseline_summary_df
# Out:
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/12.8M [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# Loading weights:   0%|          | 0/426 [00:00<?, ?it/s]
# qwen35_4b / afqmc:   0%|          | 0/200 [00:00<?, ?it/s]
# {'model_key': 'qwen35_4b', 'model_id': 'Qwen/Qwen3.5-4B', 'task': 'afqmc', 'split': 'validation', 'samples': 200, 'accuracy': 0.73, 'macro_f1': 0.6299342105263157, 'invalid_rate': 0.0, 'seconds': 222.08544611930847, 'samples_per_second': 0.9005542843746557}
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/426 [00:00<?, ?it/s]
# qwen35_4b / tnews:   0%|          | 0/200 [00:00<?, ?it/s]
# {'model_key': 'qwen35_4b', 'model_id': 'Qwen/Qwen3.5-4B', 'task': 'tnews', 'split': 'validation', 'samples': 200, 'accuracy': 0.05, 'macro_f1': 0.007889546351084813, 'invalid_rate': 0.0, 'seconds': 248.05739092826843, 'samples_per_second': 0.8062650310541831}
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/426 [00:00<?, ?it/s]
# qwen35_4b / cmnli:   0%|          | 0/200 [00:00<?, ?it/s]
# {'model_key': 'qwen35_4b', 'model_id': 'Qwen/Qwen3.5-4B', 'task': 'cmnli', 'split': 'validation', 'samples': 200, 'accuracy': 0.0, 'macro_f1': 0.0, 'invalid_rate': 0.0, 'seconds': 239.51877403259277, 'samples_per_second': 0.8350076139450546}
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/881 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/32.2M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/16.0G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/2076 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# gemma_e4b / afqmc:   0%|          | 0/200 [00:00<?, ?it/s]
# {'model_key': 'gemma_e4b', 'model_id': 'google/gemma-4-E4B', 'task': 'afqmc', 'split': 'validation', 'samples': 200, 'accuracy': 0.025, 'macro_f1': 0.03745318352059925, 'invalid_rate': 0.895, 'seconds': 208.6830940246582, 'samples_per_second': 0.9583910039994318}
# Loading weights:   0%|          | 0/2076 [00:00<?, ?it/s]
# gemma_e4b / tnews:   0%|          | 0/200 [00:00<?, ?it/s]
# {'model_key': 'gemma_e4b', 'model_id': 'google/gemma-4-E4B', 'task': 'tnews', 'split': 'validation', 'samples': 200, 'accuracy': 0.035, 'macro_f1': 0.010174418604651164, 'invalid_rate': 0.665, 'seconds': 246.8986611366272, 'samples_per_second': 0.8100489450986746}
# Loading weights:   0%|          | 0/2076 [00:00<?, ?it/s]
# gemma_e4b / cmnli:   0%|          | 0/200 [00:00<?, ?it/s]
# {'model_key': 'gemma_e4b', 'model_id': 'google/gemma-4-E4B', 'task': 'cmnli', 'split': 'validation', 'samples': 200, 'accuracy': 0.0, 'macro_f1': 0.0, 'invalid_rate': 0.235, 'seconds': 234.47029089927673, 'samples_per_second': 0.8529865307580293}
#    model_key            model_id   task       split  samples  accuracy  \
# 0  qwen35_4b     Qwen/Qwen3.5-4B  afqmc  validation      200     0.730
# 1  qwen35_4b     Qwen/Qwen3.5-4B  tnews  validation      200     0.050
# 2  qwen35_4b     Qwen/Qwen3.5-4B  cmnli  validation      200     0.000
# 3  gemma_e4b  google/gemma-4-E4B  afqmc  validation      200     0.025
# 4  gemma_e4b  google/gemma-4-E4B  tnews  validation      200     0.035
# 5  gemma_e4b  google/gemma-4-E4B  cmnli  validation      200     0.000
#
#    macro_f1  invalid_rate     seconds  samples_per_second
# 0  0.629934         0.000  222.085446            0.900554
# 1  0.007890         0.000  248.057391            0.806265
# 2  0.000000         0.000  239.518774            0.835008
# 3  0.037453         0.895  208.683094            0.958391
# 4  0.010174         0.665  246.898661            0.810049
# 5  0.000000         0.235  234.470291            0.852987

# %%
baseline_summary_df
# Out:
#    model_key            model_id   task       split  samples  accuracy  \
# 0  qwen35_4b     Qwen/Qwen3.5-4B  afqmc  validation      200     0.730
# 1  qwen35_4b     Qwen/Qwen3.5-4B  tnews  validation      200     0.050
# 2  qwen35_4b     Qwen/Qwen3.5-4B  cmnli  validation      200     0.000
# 3  gemma_e4b  google/gemma-4-E4B  afqmc  validation      200     0.025
# 4  gemma_e4b  google/gemma-4-E4B  tnews  validation      200     0.035
# 5  gemma_e4b  google/gemma-4-E4B  cmnli  validation      200     0.000
#
#    macro_f1  invalid_rate     seconds  samples_per_second
# 0  0.629934         0.000  222.085446            0.900554
# 1  0.007890         0.000  248.057391            0.806265
# 2  0.000000         0.000  239.518774            0.835008
# 3  0.037453         0.895  208.683094            0.958391
# 4  0.010174         0.665  246.898661            0.810049
# 5  0.000000         0.235  234.470291            0.852987

# %% [markdown]
# ## 6. Prepare supervised fine-tuning data
#
# This converts CLUE classification rows into instruction-response text.

# %%
def format_sft_example(task: str, ex: Dict[str, Any]) -> Dict[str, str]:
    prompt = build_prompt(task, ex, TASK_LABELS[task])
    return {"text": prompt + get_gold_label(task, ex)}

def make_sft_dataset(task: str, max_train_samples: int = MAX_TRAIN_SAMPLES):
    ds = load_dataset("clue", task, split="train")
    ds = ds.select(range(min(max_train_samples, len(ds))))
    return ds.map(lambda ex: format_sft_example(task, ex), remove_columns=ds.column_names)

sample_sft = make_sft_dataset("afqmc", 3)
print(sample_sft[0]["text"])

# %% [markdown]
# ## 7. LoRA fine-tuning
#
# Hugging Face PEFT LoRA training can be slower or more fragile on MPS than CUDA. Start with 200–1000 samples. If this fails on Mac, use a CUDA machine or switch to MLX-LM LoRA.

# %%
def train_lora_for_task(model_key: str, model_id: str, task: str, out_dir: Optional[str] = None, max_train_samples: int = MAX_TRAIN_SAMPLES, epochs: float = 1.0):
    if not PEFT_AVAILABLE:
        raise RuntimeError("PEFT/TRL is not available. Re-run the install cell and restart kernel.")
    out_dir = out_dir or f"{ADAPTERS_DIR}/{model_key}_{task}_lora"
    os.makedirs(out_dir, exist_ok=True)
    tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token
    kwargs = dict(trust_remote_code=True)
    if DEVICE == "cuda":
        kwargs.update(torch_dtype=torch.float16, device_map="auto")
    elif DEVICE == "mps":
        kwargs.update(torch_dtype=torch.float16)
    else:
        kwargs.update(torch_dtype=torch.float32)
    model = AutoModelForCausalLM.from_pretrained(model_id, **kwargs)
    if DEVICE in ["mps", "cpu"]:
        model.to(DEVICE)
    train_ds = make_sft_dataset(task, max_train_samples)
    lora_config = LoraConfig(r=16, lora_alpha=32, lora_dropout=0.05, bias="none", task_type="CAUSAL_LM", target_modules=["q_proj", "k_proj", "v_proj", "o_proj"])
    training_args = TrainingArguments(output_dir=out_dir, per_device_train_batch_size=1, gradient_accumulation_steps=8, learning_rate=2e-4, num_train_epochs=epochs, logging_steps=10, save_steps=250, save_total_limit=2, fp16=(DEVICE == "cuda"), bf16=False, report_to="none", remove_unused_columns=False)
    trainer = SFTTrainer(model=model, args=training_args, train_dataset=train_ds, peft_config=lora_config, tokenizer=tokenizer, dataset_text_field="text", max_seq_length=512)
    trainer.train()
    trainer.save_model(out_dir)
    tokenizer.save_pretrained(out_dir)
    del trainer, model
    cleanup_memory()
    return out_dir

# %%
# Example: fine-tune both models on AFQMC.
# Uncomment when ready. Start with MAX_TRAIN_SAMPLES=200 for a smoke test.

# trained_adapters = {}
# for model_key, model_id in MODELS.items():
#     adapter_dir = train_lora_for_task(model_key=model_key, model_id=model_id, task="afqmc", max_train_samples=MAX_TRAIN_SAMPLES, epochs=1.0)
#     trained_adapters[(model_key, "afqmc")] = adapter_dir
#     print(model_key, adapter_dir)

# %% [markdown]
# ## 8. Evaluate LoRA adapters

# %%
def load_causal_lm_with_adapter(model_id: str, adapter_dir: str):
    tokenizer = AutoTokenizer.from_pretrained(adapter_dir, trust_remote_code=True)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token
    kwargs = dict(trust_remote_code=True)
    if DEVICE == "cuda":
        kwargs.update(torch_dtype=torch.float16, device_map="auto")
    elif DEVICE == "mps":
        kwargs.update(torch_dtype=torch.float16)
    else:
        kwargs.update(torch_dtype=torch.float32)
    base = AutoModelForCausalLM.from_pretrained(model_id, **kwargs)
    if DEVICE in ["mps", "cpu"]:
        base.to(DEVICE)
    model = PeftModel.from_pretrained(base, adapter_dir)
    model.eval()
    return tokenizer, model

def evaluate_adapter_on_task(model_key: str, model_id: str, adapter_dir: str, task: str, split: str = SPLIT, max_samples: int = MAX_EVAL_SAMPLES):
    labels = TASK_LABELS[task]
    ds = load_task_dataset(task, split, max_samples)
    tokenizer, model = load_causal_lm_with_adapter(model_id, adapter_dir)
    rows = []
    start = time.time()
    for ex in tqdm(ds, desc=f"{model_key}+LoRA / {task}"):
        prompt = build_prompt(task, ex, labels)
        raw = generate_answer(tokenizer, model, prompt)
        pred = extract_label(raw, labels)
        gold = get_gold_label(task, ex)
        rows.append({"model_key": model_key, "model_id": model_id, "adapter_dir": adapter_dir, "task": task, "split": split, "gold": gold, "pred": pred, "raw_output": raw, "prompt": prompt})
    elapsed = time.time() - start
    del model
    cleanup_memory()
    df = pd.DataFrame(rows)
    valid_pred = df["pred"].where(df["pred"].isin(labels), "__invalid__")
    summary = {"model_key": model_key + "+lora", "model_id": model_id, "adapter_dir": adapter_dir, "task": task, "split": split, "samples": len(df), "accuracy": accuracy_score(df["gold"], valid_pred), "macro_f1": f1_score(df["gold"], valid_pred, average="macro", zero_division=0), "invalid_rate": float((valid_pred == "__invalid__").mean()), "seconds": elapsed, "samples_per_second": len(df) / max(elapsed, 1e-9)}
    return df, summary

# %%
# Evaluate trained adapters. Uncomment after running fine-tuning.

# adapter_rows, adapter_summaries = [], []
# for (model_key, task), adapter_dir in trained_adapters.items():
#     df_task, summary = evaluate_adapter_on_task(model_key, MODELS[model_key], adapter_dir, task)
#     adapter_rows.append(df_task)
#     adapter_summaries.append(summary)
# pd.concat(adapter_rows, ignore_index=True).to_csv(f"{RESULTS_DIR}/adapter_predictions.csv", index=False)
# pd.DataFrame(adapter_summaries).to_csv(f"{RESULTS_DIR}/adapter_summary.csv", index=False)
# pd.DataFrame(adapter_summaries)

# %% [markdown]
# ## 9. Compare results and inspect errors

# %%
def load_if_exists(path):
    return pd.read_csv(path) if os.path.exists(path) else pd.DataFrame()

baseline = load_if_exists(f"{RESULTS_DIR}/baseline_summary.csv")
adapter = load_if_exists(f"{RESULTS_DIR}/adapter_summary.csv")
comparison = pd.concat([baseline, adapter], ignore_index=True)
if not comparison.empty:
    display(comparison.sort_values(["task", "macro_f1"], ascending=[True, False]))
else:
    print("No result files yet. Run baseline and/or adapter evaluation cells first.")

# %%
preds = load_if_exists(f"{RESULTS_DIR}/baseline_predictions.csv")
if not preds.empty:
    errors = preds[preds["gold"] != preds["pred"]].copy()
    display(errors[["model_key", "task", "gold", "pred", "raw_output", "prompt"]].head(20))
else:
    print("No baseline prediction file yet.")

# %% [markdown]
# ## 10. Recommended experiment protocol
#
# 1. Run baseline zero-shot evaluation on all selected CLUE tasks.
# 2. Fine-tune one task at a time using the same number of training samples for both models.
# 3. Re-evaluate the matching task first, then optionally test transfer to other tasks.
# 4. Track `accuracy`, `macro_f1`, `invalid_rate`, `seconds`, and `samples_per_second`.
# 5. Keep raw predictions so label-format failures can be separated from understanding failures.
